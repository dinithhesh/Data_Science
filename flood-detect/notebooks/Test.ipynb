# %%
pip install fastapi uvicorn joblib scikit-learn pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys, os
project_root = "/content/drive/MyDrive/flood-detect"

if project_root not in sys.path:
    sys.path.append(project_root)

# %%
# !uvicorn /content/drive/MyDrive/flood-detect/api/app:app --reload --port 8000
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [1042] using StatReload
# ERROR:    Error loading ASGI app. Could not import module "/content/drive/MyDrive/flood-detect/api/app".
# INFO:     Stopping reloader process [1042]
# ^C

# %%
# !pip install pyngrok

# %%
# %cd /content/drive/MyDrive/flood-detect
from pyngrok import ngrok


# !ngrok config add-authtoken 343T4Xhn0YKBoD1zxuWeNdM5iJ1_7CrtkNy8ZDHWU1wA8uNhx

# Start tunnel on port 8000
public_url = ngrok.connect(8000)
print("🌐 Public URL:", public_url)

# Run your FastAPI server
# !uvicorn api.app:app --host 0.0.0.0 --port 8000 --reload
# Out:
# /content/drive/MyDrive/flood-detect
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# 🌐 Public URL: NgrokTunnel: "https://zula-cataractous-semibiologically.ngrok-free.dev" -> "http://localhost:8000"
# INFO:     Will watch for changes in these directories: ['/content/drive/MyDrive/flood-detect']
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [27575] using StatReload
# ✅ Model loaded from /content/drive/MyDrive/flood-detect/api/../models/model.pkl
# INFO:     Started server process [27577]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     2407:c00:6002:e132:f957:f9f:6f5e:dd4c:0 - "GET / HTTP/1.1" 200 OK

# %%
# %cd /content/drive/MyDrive/flood-detect
# !uvicorn api.app:app --reload
# Out:
# /content/drive/MyDrive/flood-detect
# INFO:     Will watch for changes in these directories: ['/content/drive/MyDrive/flood-detect']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [4959] using StatReload
# ✅ Model loaded from /content/drive/MyDrive/flood-detect/api/../models/model.pkl
# INFO:     Started server process [4961]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [4961]
# INFO:     Stopping reloader process [4959]

# %%
# !touch /content/drive/MyDrive/flood-detect/api/__init__.py
