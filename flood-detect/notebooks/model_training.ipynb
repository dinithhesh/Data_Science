# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys, os
project_root = "/content/drive/MyDrive/flood-detect"
src_path = os.path.join(project_root, "src")
if src_path not in sys.path:
    sys.path.append(src_path)

from data_loader import load_data
from train import train_model

# %%
df = load_data()
df
# Out:
#             timestamp location_id  precip_1h  precip_24h  soil_moisture  \
# 0    2025-09-24 00:00  Colombo_01       2.01       60.04           0.67
# 1    2025-09-24 01:00  Colombo_01       5.71       81.51           0.48
# 2    2025-09-24 02:00  Colombo_01       1.79       51.21           0.34
# 3    2025-09-24 03:00  Colombo_01      14.39       45.45           0.30
# 4    2025-09-24 04:00  Colombo_01       3.79       39.54           0.40
# ..                ...         ...        ...         ...            ...
# 995  2025-11-04 11:00  Colombo_01       1.11       63.34           0.38
# 996  2025-11-04 12:00  Colombo_01       4.87       37.53           0.58
# 997  2025-11-04 13:00  Colombo_01       2.63       60.51           0.41
# 998  2025-11-04 14:00  Colombo_01       2.15       47.23           0.76
# 999  2025-11-04 15:00  Colombo_01       0.95       51.32           0.24
#
#      temperature  elevation  slope  impervious_frac land_use  flood_event
# ...

# %%
print(df.columns)
# Out:
# Index(['timestamp', 'location_id', 'precip_1h', 'precip_24h', 'soil_moisture',
#        'temperature', 'elevation', 'slope', 'impervious_frac', 'land_use',
#        'flood_event'],
#       dtype='object')

# %%
MODEL_SAVE_PATH = '/content/drive/MyDrive/flood-detect/models'
best_model, results = train_model(df, target_col='flood_event', save_dir = MODEL_SAVE_PATH)

results
# Out:
# /content/drive/MyDrive/flood-detect/src/train.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["timestamp"] = pd.to_datetime(X["timestamp"], errors='coerce').astype(int) / 10**9
# Logistic Regression: Accuracy=0.515, F1=0.497, ROC-AUC=0.538
# Random Forest: Accuracy=0.520, F1=0.525, ROC-AUC=0.546
# Gradient Boosting: Accuracy=0.545, F1=0.538, ROC-AUC=0.538
# SVM: Accuracy=0.560, F1=0.506, ROC-AUC=0.577
# XGBoost: Accuracy=0.505, F1=0.507, ROC-AUC=0.522
# [LightGBM] [Info] Number of positive: 400, number of negative: 400
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000104 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 960
# ...

# %%
print(f"Is '{src_path}' in sys.path? {src_path in sys.path}")
data_loader_path = os.path.join(src_path, "data_loader.py")
print(f"Does '{data_loader_path}' exist? {os.path.exists(data_loader_path)}")
# Out:
# Is '/content/drive/MyDrive/data-science-project/src' in sys.path? True
# Does '/content/drive/MyDrive/data-science-project/src/data_loader.py' exist? False
