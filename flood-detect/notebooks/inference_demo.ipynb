# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, sys
project_root = "/content/drive/MyDrive/flood-detect"
src_path = os.path.join(project_root, "src")
if src_path not in sys.path:
    sys.path.append(src_path)

# %%
import pandas as pd
from predict import load_model, predict_flood_event, preprocess_input
from data_loader import load_data

# %%
# Load model and data
model = load_model(os.path.join(project_root, "models", "model.pkl"))
df = load_data()
df.head()
# Out:
# ✅ Model loaded from /content/drive/MyDrive/flood-detect/models/model.pkl
#           timestamp location_id  precip_1h  precip_24h  soil_moisture  \
# 0  2025-09-24 00:00  Colombo_01       2.01       60.04           0.67
# 1  2025-09-24 01:00  Colombo_01       5.71       81.51           0.48
# 2  2025-09-24 02:00  Colombo_01       1.79       51.21           0.34
# 3  2025-09-24 03:00  Colombo_01      14.39       45.45           0.30
# 4  2025-09-24 04:00  Colombo_01       3.79       39.54           0.40
#
#    temperature  elevation  slope  impervious_frac land_use  flood_event
# 0         28.8        5.2    2.9             0.65    Urban            1
# 1         29.1        9.3    2.6             0.79    Urban            1
# 2         29.6       13.8    3.7             0.63    Urban            1
# 3         26.8        8.0    2.5             0.62    Urban            1
# 4         27.6        5.9    2.1             0.72    Urban            0

# %%
sample_data = df.sample(10, random_state=42)
preds = predict_flood_event(model, sample_data)

display(preds[["precip_1h", "slope", "elevation", "predicted_flood_event", "probability"]])
# Out:
# ✅ Prediction completed successfully.
#      precip_1h  slope  elevation  predicted_flood_event  probability
# 521      10.96    2.2       12.3                      1     0.534095
# 737       3.96    1.4       13.4                      1     0.507717
# 740       3.83    0.3        7.2                      1     0.505878
# 660       5.28    3.3        8.4                      0     0.500000
# 411       5.03    1.7        5.9                      0     0.465320
# 678       6.99    4.1        5.6                      1     0.521778
# 626       1.68    4.7       13.8                      0     0.464228
# 513       1.64    2.5        8.4                      0     0.500000
# 859       1.76    2.6       14.7                      1     0.521646
# 136       4.80    1.9       11.0                      0     0.480254

# %%
custom_input = pd.DataFrame([{
    "precip_1h": 15.2,
    "slope": 3.4,
    "elevation": 42.1,
    "timestamp": 1625205600,   # Example UNIX time
    "precip_24h": 78.5,
    "impervious_frac": 0.65
}])

prediction = predict_flood_event(model, custom_input)
print(prediction)
# Out:
# ✅ Prediction completed successfully.
#    precip_1h  slope  elevation   timestamp  precip_24h  impervious_frac  \
# 0       15.2    3.4       42.1  1625205600        78.5             0.65
#
#    predicted_flood_event  probability
# 0                      1     0.507351
